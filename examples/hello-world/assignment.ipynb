# %% [markdown]
# # Hello World
#
# Welcome to your first Python notebook! Click on each code cell below and press **Shift+Enter** to run it.

# %%
# Run this cell by clicking it and pressing Shift+Enter
print("Hello, World!")

# %% [markdown]
# ## Try It Yourself
#
# Edit the cell below to print your own message, then run it.

# %%
# Change the message below and press Shift+Enter to run
my_name = "Student"
print(f"Hello, {my_name}! Welcome to Python.")

# %% [markdown]
# ## Basic Math
#
# Python can do math. Try changing the numbers and running the cell again.

# %%
a = 10
b = 3

print(f"{a} + {b} = {a + b}")
print(f"{a} - {b} = {a - b}")
print(f"{a} * {b} = {a * b}")
print(f"{a} / {b} = {a / b:.2f}")

# %% [markdown]
# When you're done, click the **Submit** button in the toolbar above.
